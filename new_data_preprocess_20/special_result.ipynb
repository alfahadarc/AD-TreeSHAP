# %%
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt

# %%
npzfile = np.load('data/data_d1_d2_data.npz')
features = npzfile['features']
labels = npzfile['labels']
groups = npzfile['groups']
features = np.nan_to_num(features)

# %%
shap_interaction_values_load = np.load("values/interaction_value_d1_d2.npz")
shap_interaction_values = shap_interaction_values_load["values"]

# %%
column_names = pd.read_csv('column_used', delimiter=",")
column_names = column_names.columns
len(column_names)
# Out:
# 20

# %%
shap.dependence_plot((1,9), shap_interaction_values[2], features,interaction_index=None,feature_names=column_names, show=False)
plt.gcf().savefig("fet_1_9_AD.pdf", format="pdf", bbox_inches="tight")

# %%
shap.dependence_plot((7,7), shap_interaction_values[0], features,interaction_index=None, show=True)

# %%
shap.dependence_plot((13,13), shap_interaction_values[0], features,interaction_index=None, show=True)

# %%
shap.dependence_plot((13,7), shap_interaction_values[0], features,interaction_index=None, feature_names=column_names, show=False)
plt.gcf().savefig("fet_13_7_CN.pdf", format="pdf", bbox_inches="tight")
shap.dependence_plot((13,13), shap_interaction_values[0], features,interaction_index=None, feature_names=column_names, show=False)
plt.gcf().savefig("fet_13_13_CN.pdf", format="pdf", bbox_inches="tight")
shap.dependence_plot((7,7), shap_interaction_values[0], features,interaction_index=None, feature_names=column_names, show=False)
plt.gcf().savefig("fet_7_7_CN.pdf", format="pdf", bbox_inches="tight")

# %%
loaded_data = np.load("values/shap_value_d1_d2.npz")
zero = loaded_data["zero"]
one = loaded_data["one"]
two = loaded_data["two"]
loaded_array = [zero, one, two]

# %%
for i in [13,7,8,9,12,1,3]:
    shap.dependence_plot(i, loaded_array[2], features,show=True)

# %%
shap.dependence_plot(7, loaded_array[2], features,show=False)

# %%
shap.dependence_plot((1,9), shap_interaction_values[2], features,interaction_index=None, show=True)

# %%
shap.dependence_plot((9,9), shap_interaction_values[2], features,interaction_index=None, show=True)

# %%
import pandas as pd
import numpy as np
import shap
import matplotlib.pyplot as plt

# %%
npzfile = np.load('data/data_d1_d2_data.npz')
features = npzfile['features']
labels = npzfile['labels']
groups = npzfile['groups']
features = np.nan_to_num(features)

# %%
shap_interaction_values_load = np.load("values/interaction_value_d1_d2.npz")
shap_interaction_values = shap_interaction_values_load["values"]

# %%
shap.dependence_plot((25, 11), shap_interaction_values[1], features[:,:],  show=False)

# %%
shap.dependence_plot((11, 11), shap_interaction_values[1], features[:,:],  show=False)

# %%
shap.dependence_plot((25, 25), shap_interaction_values[1], features[:,:],  show=False)
